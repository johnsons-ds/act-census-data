# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('act-total-income-data-weekly.csv', skiprows=9)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                            SEXP Sex
# 1                                                Male
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
